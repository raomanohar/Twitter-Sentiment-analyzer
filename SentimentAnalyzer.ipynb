# %%
import tweepy
from textblob import TextBlob
from googletrans import Translator

ACCESS_TOKEN = "859108424-kXjc2uF9Q97O8oJlJswKJSyZK0jQAveXeg4NNjzs"
ACCESS_TOKEN_SECRET = "5mzmbOhsmT5Mshz7DBiSBCW3Qop9RuVztgsfe64Lqt8QQ"
CONSUMER_KEY = "LMTTQcPtYRvEFkBHXSNH53Ilp"
CONSUMER_SECRET = "RpJbJM7Z5LcXOZwdQYWka1j9l71WkpQS64LpV1BYiaNVYttNYI"

## Creating a Translatop object
translator = Translator()

class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):

        print("--------------------")
        try:
            m = status.extended_tweet["full_text"]
            m = ''.join(c for c in m if c <= '\uFFFF') #Removes Emojies for the googletrans API to work"""

            translations = translator.translate(m, dest='en')
            print('\033[1m{:10s}\033[0m'.format('Tweet in Portuguese \n'), translations.origin, "\n")
            print('\033[1m{:10s}\033[0m'.format("Tweet translated to English \n"),  translations.text)
            z = translations.text
                        
        except AttributeError:
            m = status.text
            m = ''.join(c for c in m if c <= '\uFFFF') #Removes Emojies for the googletrans API to work"""

            translations = translator.translate(m, dest='en')
            print('\033[1m{:10s}\033[0m'.format('Tweet in Portuguese \n'), translations.origin, "\n")
            print('\033[1m{:10s}\033[0m'.format("Tweet translated to English \n"),  translations.text)
            z = translations.text


        analysis = TextBlob(z)

        if analysis.sentiment.polarity > 0:
            print('\033[92m{:10s}\033[0m'.format("Sentiment of the tweet is Positiv"))
        elif analysis.sentiment.polarity == 0:
            print('\033[93m{:10s}\033[0m'.format("Sentiment of the tweet is Neutral"))
        else:
            print('\033[91m{:10s}\033[0m'.format("Sentiment of the tweet is Negative"))
        print("--------------------\n")

    def on_error(self, status):
        print(status)

if __name__ == "__main__":

    auth = tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN,ACCESS_TOKEN_SECRET)
    API = tweepy.API(auth)

    myStreamListener = MyStreamListener()
    myStream = tweepy.Stream(auth = API.auth, listener=myStreamListener, tweet_mode='extended')

    myStream.filter(track=['Avengers'],languages=['pt'])
# Out:
# --------------------
# Tweet in Portuguese
#  @pagnorenata Vamo ve avengers amanha 21h
#
# Tweet translated to English
#  @pagnorenata Vamo ve avengers tomorrow 21h
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  eu gostei q a funko, normalmente a maior spoilerzera q temos, segurou os funkos de avengers até o primeiro fds do filme...
#
# Tweet translated to English
#  I like the funko, usually the biggest spoiler we have, held the funkos of avengers until the first fds of the movie ...
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  Ele é patriots. Eu sabia que eu torcia pro homem certo
#
# Tweet translated to English
#  He is patriots. I knew I wanted the right man
# Sentiment of the tweet is Positiv
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @stuckysz: Steve Rogers depois de Endgame:
# - digno do Mjolnir e do trono de Asgard
# - bunda americana da nação
# - força do ódio mesmo com…
#
# Tweet translated to English
#  RT @stuckysz: Steve Rogers after Endgame:
# - Worthy of the Mjolnir and the Throne of Asgard
# - American Ass of the Nation
# - Hate force even with ...
# Sentiment of the tweet is Negative
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @tiredamumu: VAZOU novo filme dos vingadores saindo em 2020
#
#  o titulo é avengers: sevenfold
#
# Tweet translated to English
#  RT @Robertson: I do not know what to do.
#
#  the title is avengers: sevenfold
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  sla parece q algm recortou e colou a cara no thor????
#
# Tweet translated to English
#  Sla seems q algm trimmed and sneaked in thor ????
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @candidatonica: ator do filme Avengers posta foto com a legenda: eu e meus amigos queremos comer o SEU CU https://t.co/lza20BZsXs
#
# Tweet translated to English
#  RT @candidatonica: Avengers movie actor posts photo with caption: me and my friends want to eat YOUR CU https://t.co/lza20BZsXs
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @tiredamumu: VAZOU novo filme dos vingadores saindo em 2020
#
#  o titulo é avengers: sevenfold
#
# Tweet translated to English
#  RT @Robertson: I do not know what to do.
#
#  the title is avengers: sevenfold
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  @gabriela_rs13 O pior possível?! CADÊ MEU AMIGO PRA ME CHAMAR PRA TROCAR FIGURINHA DO ÁLBUM DOS AVENGERS
#
# Tweet translated to English
#  @ gabriela_rs13 The worst possible ?! GIVE MY FRIEND TO CALL ME TO CHANGE AVENGERS 'ALBUMS
# Sentiment of the tweet is Negative
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @tiredamumu: VAZOU novo filme dos vingadores saindo em 2020
#
#  o titulo é avengers: sevenfold
#
# Tweet translated to English
#  RT @Robertson: I do not know what to do.
#
#  the title is avengers: sevenfold
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  nada alem do esperado
#
# Tweet translated to English
#  nothing more than expected
# Sentiment of the tweet is Positiv
# --------------------
#
# --------------------
# Tweet in Portuguese
#  Cansada porém assisti avengers again
#
# Tweet translated to English
#  Tired though watched avengers again
# Sentiment of the tweet is Negative
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @abrahaomendes: Zoe Saldana é o amuleto de sorte da indústria do cinema https://t.co/OveyfaH0WN
#
# Tweet translated to English
#  RT @abrahaomendes: Zoe Saldana is the lucky amulet of the movie industry https://t.co/OveyfaH0WN
# Sentiment of the tweet is Positiv
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @cherryllodge: apreciem essa obra de arte a abertura de Brooklyn nine nine versão avengers https://t.co/Gy3nxqYKtB
#
# Tweet translated to English
#  RT @cherryllodge: appreciate this work of art the opening of Brooklyn nine nine version avengers https://t.co/Gy3nxqYKtB
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @cherryllodge: apreciem essa obra de arte a abertura de Brooklyn nine nine versão avengers https://t.co/Gy3nxqYKtB
#
# Tweet translated to English
#  RT @cherryllodge: appreciate this work of art the opening of Brooklyn nine nine version avengers https://t.co/Gy3nxqYKtB
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @nacaomarvelofc: #AvengersEndgame já e a 5ª maior bilheteria da história do cinema, em pouco mais de 10 dias em exibição ao redor do mun…
#
# Tweet translated to English
#  RT @nacaomarvelofc: #AvengersEndgame is already the 5th biggest box office in the history of cinema, in little more than 10 days on display around the world ...
# Sentiment of the tweet is Positiv
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @hogwspider:
#
#             CHÁ DE REVELAÇÃO
#
#
#
# gostaria de revelar que eu ainda não superei ave…
#
# Tweet translated to English
#  RT @hogwspider:
#
#             REVELATION TEA
#
#
#
# I would like to reveal that I have not yet overcome bird ...
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#
#
#             CHÁ DE REVELAÇÃO:
#
#     Chorei de soluçar no cinema enquanto
#                Avengers Endgame
#
#
#
# Tweet translated to English
#  REVELATION TEA:
#
#     I cried of sobbing in the movies while
#                Avengers Endgame
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @tiredamumu: VAZOU novo filme dos vingadores saindo em 2020
#
#  o titulo é avengers: sevenfold
#
# Tweet translated to English
#  RT @Robertson: I do not know what to do.
#
#  the title is avengers: sevenfold
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @NinjaRosaChoque: Gado que é gado volta no tempo pra ficar com a mina. ksksks
# #avengers
#
# Tweet translated to English
#  RT @NinjaRosaChoque: Livestock that comes back in time to be with the mine. ksksks
# #avengers
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  Tony Stark é melhor avengers da marvel
#
# Tweet translated to English
#  Tony Stark is the best marvel avengers
# Sentiment of the tweet is Positiv
# --------------------
#
# --------------------
# Tweet in Portuguese
#  RT @tiredamumu: VAZOU novo filme dos vingadores saindo em 2020
#
#  o titulo é avengers: sevenfold
#
# Tweet translated to English
#  RT @Robertson: I do not know what to do.
#
#  the title is avengers: sevenfold
# Sentiment of the tweet is Neutral
# --------------------
#
# --------------------
# Tweet in Portuguese
#  meus amores vocês vao continuar acompanhando o mcu depois de avengers endgame
#
# Tweet translated to English
#  my loves you guys will continue following the mcu after avengers endgame
# Sentiment of the tweet is Neutral
# --------------------
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-9502c293b38c> in <module>()
#      57     myStream = tweepy.Stream(auth = API.auth, listener=myStreamListener, tweet_mode='extended')
#      58
# ---> 59     myStream.filter(track=['Avengers'],languages=['pt'])
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/http/client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/http/client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/http/client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/http/client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/util/selectors.py in select(self, timeout)
#     436             fd_events = _syscall_wrapper(self._epoll.poll, True,
#     437                                          timeout=timeout,
# --> 438                                          maxevents=max_events)
#     439             for fd, event_mask in fd_events:
#     440                 events = 0
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:
